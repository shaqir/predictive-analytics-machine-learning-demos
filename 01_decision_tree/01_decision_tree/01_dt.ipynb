# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
import pandas as pd

iris = load_iris()
X = iris.data
y = iris.target

df = pd.DataFrame(X, columns=iris.feature_names)
df['Species'] = iris

df.shape
# Out:
# (150, 5)

# %%
### Splitting The dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=46, test_size=0.3)

# %% [markdown]
# ### Train Model

# %%
dt = DecisionTreeClassifier(max_depth=3, random_state=46)

# %%
dt.fit(X_train, y_train)
dt
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=46)

# %% [markdown]
# ### Testing the model

# %%
y_pred  = dt.predict(X_test)

# %%
print(f'Accuracy is : {accuracy_score(y_test,y_pred)}')
# Out:
# Accuracy is : 0.9111111111111111

# %%
print(classification_report(y_test, y_pred, target_names=iris.target_names))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        17
#   versicolor       0.85      0.85      0.85        13
#    virginica       0.87      0.87      0.87        15
#
#     accuracy                           0.91        45
#    macro avg       0.90      0.90      0.90        45
# weighted avg       0.91      0.91      0.91        45

# %% [markdown]
# #### Plot the decision Tree

# %%
plt.Figure(figsize=(14,6))
plot_tree(dt, 
          feature_names=iris.feature_names, 
          class_names=iris.target_names, 
          fontsize=10)
plt.show()

# %%
features = iris.feature_names
importance = dt.feature_importances_
best_feature = features[importance.argmax()]
best_feature
# Out:
# 'petal length (cm)'

# %%
dt.feature_importances_
# Out:
# array([0.        , 0.        , 0.53982269, 0.46017731])
