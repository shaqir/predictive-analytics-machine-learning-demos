# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
url = 'https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/insurance.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
le = LabelEncoder()
df['sex'] = le.fit_transform(df['sex'])
df['smoker'] = le.fit_transform(df['smoker'])
df = pd.get_dummies(df, columns=['region'])

# %%
df
# Out:
#       age  sex     bmi  children  smoker      charges  region_northeast  \
# 0      19    0  27.900         0       1  16884.92400             False
# 1      18    1  33.770         1       0   1725.55230             False
# 2      28    1  33.000         3       0   4449.46200             False
# 3      33    1  22.705         0       0  21984.47061             False
# 4      32    1  28.880         0       0   3866.85520             False
# ...   ...  ...     ...       ...     ...          ...               ...
# 1333   50    1  30.970         3       0  10600.54830             False
# 1334   18    0  31.920         0       0   2205.98080              True
# 1335   18    0  36.850         0       0   1629.83350             False
# 1336   21    0  25.800         0       0   2007.94500             False
# 1337   61    0  29.070         0       1  29141.36030             False
#
#       region_northwest  region_southeast  region_southwest
# ...

# %%
X = df.drop('charges',axis=1)
y = df['charges']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,y,test_size=0.2,random_state=46
)

# %%
g_b_r = GradientBoostingRegressor(
    n_estimators=200,
    learning_rate=0.1,
    max_depth=4,
    subsample=0.8,
    random_state=46,
    loss='squared_error'
)

# %%
g_b_r.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(max_depth=4, n_estimators=200, random_state=46,
#                           subsample=0.8)

# %%
y_pred = g_b_r.predict(X_test)

# %%
print(f'MAE:{mean_absolute_error(y_test,y_pred)}\n')
print(f'RMSE:{root_mean_squared_error(y_test,y_pred)}\n')
print(f'R2:{r2_score(y_test,y_pred)}\n')
print(f'Median Charge: ${y.median():,.0f}\n')
# Out:
# MAE:2683.6972261022715
#
# RMSE:4349.716787184834
#
# R2:0.8705291828142304
#
# Median Charge: $9,382

# %%
# Which features are important from all

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

importances = g_b_r.feature_importances_
feature_names = X.columns

indices = np.argsort(importances)[::-1]

plt.figure(figsize=(10,8))

sns.barplot(x=importances[indices], y=feature_names[indices], palette="viridis")

plt.show()
# Out:
# /var/folders/vl/bc4jn9p97v161wrgq0q7wl340000gn/T/ipykernel_60934/3865508787.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=importances[indices], y=feature_names[indices], palette="viridis")

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test,y_pred)
plt.plot([y_test.min(),y_test.max()],[y_test.min(),y_test.max()],'r--',lw=2)
